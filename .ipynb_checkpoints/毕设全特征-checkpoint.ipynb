# %%
# -*- coding: utf-8 -*-
import pandas as pd
import numpy as np
import warnings
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn import metrics
from win32timezone import now
import gc
# %matplotlib inline

warnings.filterwarnings("ignore")

# %%
def feat_select(train, test):
    features = train.drop(['is_trade', 'time', 'context_timestamp'], axis=1).columns.tolist()
    feature = []
    target = ['is_trade']

    return features, target


def xgbCV(train, test, features, target):
    X = train[features]
    y = train[target]
    X_tes = test[features]
    y_tes = test[target]

    print('Training XGB model...')
    X_train_set = xgb.DMatrix(X, label=y, missing=np.nan)
    X_validate_set = xgb.DMatrix(X_tes, label=y_tes, missing=np.nan)
    watchlist = [(X_train_set, 'train'), (X_validate_set, 'eval')]
    params = {'max_depth': 7,
              'nthread': -1,
              'eta': 0.01,
              'eval_metric': 'auc',
              'objective': 'binary:logistic',
#               'objective':'rank:pairwise',
              'subsample': 0.85,
              'colsample_bytree': 0.85,
              'silent': 1,
              'seed': 0,
              'min_child_weight': 6,
              'gpu_id': 0,
              'tree_method': 'gpu_hist'
#               'max_delta_step':1,
#               'scale_pos_weight':0.5
              }
    history = xgb.cv(params, X_train_set, num_boost_round=3000, nfold=3, early_stopping_rounds=50)
    return history


def sub(train, test, features, target, best_iter_num):
    X = train[features]
    y = train[target]
    X_train_set = xgb.DMatrix(X, label=y, missing=np.nan)
    X_test_set = xgb.DMatrix(test[features], missing=np.nan)
    print('Training XGB model...')
    params = {'max_depth': 7,
              'nthread': -1,
              'eta': 0.01,
              'eval_metric': 'auc',
              'objective': 'binary:logistic',
#               'objective':'rank:pairwise',
              'subsample': 0.85,
              'colsample_bytree': 0.85,
              'silent': 1,
              'seed': 0,
              'min_child_weight': 6,
              'gpu_id': 0,
              'tree_method': 'gpu_hist'
#               'scale_pos_weight':0.5
              }
    bst = xgb.train(params, X_train_set, num_boost_round=best_iter_num)
    bst.save_model('001.model')
    return bst
    # pred = gbm.predict(X_test_set)
    # test['predicted_score'] = predr
    # sub = test[['instance_id', 'predicted_score']]
    # mean = sub['predicted_score'].mean()
    # sub[['instance_id', 'predicted_score']].to_csv('xgb_mean_%s.txt' % mean, sep=" ", index=False)


def train():
    # train_data = rebalance()
    print("starting CV:", now())
    history = xgbCV(train_data, test_data, features, target)
    best_iter=history.shape[0]
#     best_iter=1091
#     best_iter=50
    print('最佳迭代次数：', best_iter)
    return sub(train_data, test_data, features, target, best_iter)


def rebalance():
    sm = SMOTEENN()
    train_data.replace(to_replace=np.nan, value=0, inplace=True)
    train_data.replace(to_replace=-np.inf, value=0, inplace=True)
    train_data.replace(to_replace=np.inf, value=0, inplace=True)
    print("rebalance data:", now())
    X_resampled, y_resampled = sm.fit_resample(train_data[features], train_data[target])
    X_resampled = pd.DataFrame(X_resampled, columns=features)
    y_resampled = pd.DataFrame(y_resampled, columns=target)
    X_resampled['is_trade'] = y_resampled['is_trade']
    del y_resampled
    gc.collect()
    return X_resampled


def count():
    tp = 0
    tn = 0
    fp = 0
    fn = 0
    for i in range(0, len(predictions)):
        if predictions[i] == y_true.T[0][i]:
            if predictions[i] == 1:
                tp += 1
            else:
                tn += 1
        else:
            if predictions[i] == 1:
                fp += 1
            else:
                fn += 1

    print(tp, tn, fp, fn)

# %%
path = './data/'

data = pd.read_csv(path + 'all_final_data_11-07-18-51.csv')
data = data[data.is_trade.notnull()]
train_data, test_data = train_test_split(data, test_size=0.25)
features, target = feat_select(train_data, test_data)

# %%
# print("starting CV:", now())
# history = xgbCV(train_data, test_data, features, target)
# best_iter=history.shape[0]
# history

# %%
bst=train()
gc.collect()
bst = xgb.Booster({'nthread': 6})  # init model
bst.load_model('001.model')  # load data

X_test_set = xgb.DMatrix(test_data[features], missing=np.nan)
print('predicting……')
y_pred = bst.predict(X_test_set)
predictions = [round(x) for x in y_pred]
y_true = test_data[target].values
count()
# 输出模型的一些结果
print("\n关于现在这个模型")
print("准确率 : %.4g" % metrics.accuracy_score(y_true, predictions))
print("召回率:%.4f" % metrics.recall_score(y_true, predictions))
print("精度:%.4f" % metrics.precision_score(y_true, predictions))
print("F1:%.4f" % metrics.f1_score(y_true, predictions))
print("AUC 得分 (训练集): %f" % 0.906732)
print("AUC 得分 (测试集): %f" % 0.769061)
# xgb.plot_importance(alg.get_booster())
# Out:
# starting CV: 2019-01-20 23:00:49.383643+08:00
# Training XGB model...

# %%
importance = bst.get_fscore()
for key,value in importance.items():
    print(key,value)
# Out:
# u_day_diffTime_last 144
# item_price_level_mean_by_category 44
# user_id_query_day_hour_map_item_id 34
# check_item_category_1_min_diff_next 239
# item_price_level_user_age_prob 68
# item_id_user_occ_prob 28
# shop_star_level_user_age_prob 25
# item_mean_hour 13
# item_price_level_mean_by_city 13
# item_city_id 13
# user_id_query_day_hour_map_item_sales_level 3
# instance_id 65
# check_item_brand_id_min_diff_last 30
# brand_mean_hour 16
# item_price_level 17
# item_id 38
# i_day_diffTime_last 95
# item_city_id_user_prob 48
# user_id_query_day_item_id 47
# shop_score_delivery 155
# item_city_id_user_age_prob 30
# item_sales_level_mean_by_brand_ratio 28
# shop_hour_active_user 32
# check_item_price_level_min_diff_next 102
# item_sales_level_mean_by_brand 49
# item_price_level_mean_by_city_ratio 27
# item_city_id_user_occ_prob 17
# check_item_pv_level_ratio 9
# user_maphour_cnt_ratio 27
# item_id_nexttime_diff 44
# shop_star_level_user_prob 13
# item_maphour_cnt_ratio 62
# item_collected_level_salse_prob 72
# minute 31
# shop_mean_age 43
# shop_review_num_level 8
# mean_item_sales_level 69
# item_pv_level_salse_prob 37
# mean_item_price_level 73
# check_item_pv_level_min_diff_next 99
# item_city_id_brand_prob 6
# user_id 34
# user_id_lasttime_diff 50
# shop_review_positive_rate 30
# user_mean_hour 44
# item_brand_id_user_prob 54
# shop_id_user_prob 28
# shop_id_user_age_prob 13
# i_day_diffTime_first 72
# item_sales_level_mean_by_city_ratio 31
# item_price_level_shop_rev_prob 23
# click_user_brand_lab 6
# s_day_diffTime_first 17
# check_item_id_min_diff_next 39
# item_collected_level_user_prob 23
# shop_score_service 36
# shop_star_level_user_occ_prob 10
# u_day_diffTime_first 22
# item_category_list_user_gender_prob 7
# b_day_diffTime_first 33
# user_day_active_shop 10
# sale_collect 16
# user_id_query_day_hour_item_category_1 11
# user_star_level 26
# item_category_list_user_prob 33
# item_collected_level_shop_rev_prob 14
# user_id_query_day_hour_map_item_price_level 1
# item_sales_level_mean_by_category_ratio 54
# item_brand_id_user_occ_prob 12
# b_day_diffTime_last 9
# check_item_sales_level_min_diff_last 32
# user_hour_active_city 22
# item_collected_level_user_age_prob 20
# click_user_item_lab 85
# shop_id 20
# item_city_id_shop_rev_prob 48
# item_id_shop_prob 23
# hour 70
# check_item_sales_level_min_diff_next 35
# item_sales_level_shop_prob 23
# item_sales_level_user_age_prob 17
# user_day_active_city 18
# item_brand_id 11
# category_day_active_item 27
# item_pv_level_shop_prob 30
# item_hour_active_user 23
# item_id_user_gender_prob 14
# user_id_query_day_hour_item_sales_level 5
# item_hour_cnt_ratio 15
# item_collected_level 2
# user_occupation_id 5
# category_day_active_user 14
# check_item_collected_level_min_diff_next 22
# item_category_list_user_age_prob 19
# item_price_level_user_prob 33
# user_hour_active_brand 13
# item_pv_level_user_prob 43
# item_price_level_city_prob 8
# check_shop_id_min_diff_last 12
# item_price_level_brand_prob 8
# check_context_page_id_min_diff_next 42
# item_brand_id_shop_rev_prob 14
# item_pv_level_coll_prob 19
# user_id_query_day_hour_item_id 30
# gender_star 43
# sale_price 27
# item_sales_level_user_prob 33
# shop_star_level_user_gender_prob 8
# context_id 26
# item_sales_level_city_prob 16
# item_day_active_user 14
# user_id_query_day_context_page_id 5
# item_collected_level_mean_by_city 9
# item_category_1 9
# item_sales_level_shop_rev_prob 29
# check_item_sales_level_ratio 8
# brand_mean_age 23
# item_price_level_mean_by_brand 60
# user_hour_cnt_ratio 40
# item_pv_level_mean_by_category 1
# check_item_pv_level_min_diff_last 15
# item_sales_level_user_occ_prob 16
# item_pv_level_brand_prob 18
# item_id_lasttime_diff 33
# item_pv_level_mean_by_category_ratio 4
# item_mean_age 24
# day_x 7
# item_id_shop_rev_prob 11
# item_price_level_mean_by_brand_ratio 14
# shop_review_num_level_user_prob 30
# brand_day_active_user 10
# item_pv_level_user_age_prob 13
# item_price_level_mean_by_category_ratio 21
# user_id_nexttime_diff 24
# shop_day_active_user 23
# shop_star_level 16
# shop_review_num_level_user_gender_prob 6
# shop_review_num_level_user_age_prob 15
# item_id_user_prob 43
# item_price_level_shop_prob 6
# user_id_query_day_hour_item_price_level 11
# item_sales_level_brand_prob 20
# item_collected_level_mean_by_brand_ratio 12
# item_pv_level_mean_by_brand_ratio 21
# item_collected_level_price_prob 8
# check_item_category_1_min_diff_last 20
# context_page_id 13
# price_collect 17
# check_item_price_level_min_diff_last 19
# user_age_level 17
# shop_id_user_gender_prob 18
# shop_mean_hour 11
# item_pv_level_mean_by_city_ratio 13
# item_collected_level_shop_prob 15
# item_collected_level_mean_by_brand 17
# item_pv_level_shop_rev_prob 18
# user_id_query_day_hour_context_page_id 3
# item_sales_level_user_gender_prob 11
# item_pv_level_mean_by_city 4
# shop_score_description 15
# user_id_query_day_hour_map_context_page_id 6
# item_sales_level_item_prob 7
# check_context_page_id_ratio 11
# check_item_price_level_ratio 9
# item_brand_id_user_gender_prob 8
# item_pv_level_mean_by_brand 12
# item_brand_id_user_age_prob 12
# item_category_list_user_occ_prob 6
# item_collected_level_mean_by_city_ratio 5
# item_collected_level_mean_by_category 7
# item_pv_level_price_prob 26
# check_item_category_1_time_day 6
# shop_review_num_level_user_occ_prob 13
# item_collected_level_city_prob 14
# item_sales_level_mean_by_city 12
# item_brand_id_shop_prob 10
# user_id_query_day_item_pv_level 2
# item_collected_level_mean_by_category_ratio 8
# item_pv_level_city_prob 20
# item_price_level_user_gender_prob 8
# item_pv_level_user_gender_prob 6
# s_day_diffTime_last 3
# item_sales_level_price_prob 17
# item_city_id_user_gender_prob 8
# item_sales_level 3
# user_id_query_day_item_category_1 5
# item_id_user_age_prob 13
# user_active_hour 6
# check_item_pv_level_time_day 2
# item_pv_level_user_occ_prob 6
# shop_id_user_occ_prob 11
# item_pv_level 1
# check_shop_id_ratio 2
# user_id_query_day_item_price_level 7
# user_mean_age 15
# user_id_query_day_hour_item_pv_level 5
# day_y.1 1
# item_collected_level_item_prob 6
# check_item_category_1_ratio 12
# check_item_collected_level_min_diff_last 12
# user_id_query_day_item_sales_level 2
# user_gender_id 4
# check_shop_id_min_diff_next 15
# click_user_lab 5
# check_item_id_ratio 3
# check_item_id_min_diff_last 3
# user_id_query_day_item_brand_id 4
# check_context_page_id_min_diff_last 8
# item_city_id_shop_prob 4
# item_pv_level_item_prob 10
# mean_item_collected_level 4
# check_item_brand_id_min_diff_next 18
# item_sales_level_mean_by_category 4
# item_collected_level_brand_prob 17
# check_item_price_level_time_day 2
# mean_item_pv_level 9
# user_id_query_day_hour_map_item_category_1 2
# check_item_collected_level_time_day 3
# item_collected_level_user_gender_prob 4
# maphour 3
# user_day_active_brand 8
# item_collected_level_user_occ_prob 4
# check_item_brand_id_ratio 7
# click_user_shop_lab 4
# mapmin 11
# click_user_city_lab 2
# same_time_expo_cnt 2
# item_price_level_user_occ_prob 3
# user_id_query_day_hour_map_item_pv_level 1
# check_context_page_id_time_day 2
# user_id_query_day_item_collected_level 1
# user_id_query_day_hour_item_collected_level 2
# user_id_query_day_hour_item_brand_id 2
# check_item_sales_level_time_day 1
# user_id_query_day_shop_id 1
# check_shop_id_time_day 1
# user_id_query_day_hour_map_shop_id 3
